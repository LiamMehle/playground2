# %%
from threading import Thread
from nn_h import *
import numpy as np

model = generate_model()

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test  = tf.keras.utils.normalize(x_test, axis=1)
x_test  = x_test.reshape(-1, 28, 28, 1)


def print_stats(model, x_test, y_test):
    t0 = float(time.time())
    predictions = model.predict(x_test.reshape(-1, 28, 28, 1))
    t1 = float(time.time())
    prediction_time = t1-t0

    mistake_count = 0
    for i in range(len(predictions)):
        if np.argmax(predictions[i]) != y_test[i]:
            mistake_count += 1
    print(f'model mis-identified {mistake_count}/{len(y_test)} (={mistake_count/len(y_test)*100:.2f}%)')
    print(f'time taken to predict {len(y_test)} is {prediction_time}\n{prediction_time/len(y_test)*1000:.2f}ms\n{len(y_test)/prediction_time/1000:.2f}k predictions/s')
    t0 = float(time.time())
    predictions = model.predict(np.array([x_test[0]]))
    t1 = float(time.time())
    prediction_time = t1-t0
    print(f'time taken to predict {1} is {prediction_time*1000:.2f}ms\n{1/prediction_time/1000:.2f}k predictions/s')
# Out:
# --------------------------------------------------------------
# ResourceExhaustedError       Traceback (most recent call last)
# <ipython-input-17-8ef88259577f> in <module>
#       3 import numpy as np
#       4
# ----> 5 model = generate_model()
#       6
#       7 mnist = tf.keras.datasets.mnist
#
# ~/git/playground2/py/opencv/nn/nn_h.py in generate_model()
#      26         x_test  = tf.keras.utils.normalize(x_train, axis=1)
#      27
# ---> 28         model = create_model(18, [1024*8,1024*8])
#      29         #model.fit(x_train, y_train, epochs=5)
#      30         return model
#
# ~/git/playground2/py/opencv/nn/nn_h.py in create_model(conv_size, neuron_counts)
#       7         model.add(layer.Flatten())
#       8         for neuron_count in neuron_counts:
# ----> 9                 model.add(layer.Dense(neuron_count,  activation=tf.nn.relu))
#      10         model.add(layer.Dense(10  ,  activation=tf.nn.softmax))
#      11
#
# ...

# %%
x_train = x_train.reshape(-1,28,28,1)
model.fit(x_train, y_train, epochs=2)
print_errors()
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 68s 36ms/step - loss: 2.2667 - accuracy: 0.5529
# Epoch 2/2
# 1875/1875 [==============================] - 90s 48ms/step - loss: 0.4841 - accuracy: 0.8650
